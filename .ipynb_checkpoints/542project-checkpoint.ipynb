# %% [raw]
# 1. Reading-in the datasets into Pandas DataFrames from their Github location:

# %%
# call pandas
import pandas as pd # 'pd' is a nickname

gitCloudRepo='https://github.com/elenapopic542/Deliverable1/raw/main/'
fileName="GDPGrowth_Data.csv"

DF1csv=pd.read_csv(gitCloudRepo + fileName)

DF1csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                        Indicator Name     Indicator Code  1960      1961  \
# 0    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 1    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN -2.360093
# 2    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 3    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN -0.274916
# ...

# %%
gitCloudRepo='https://github.com/elenapopic542/Deliverable1/raw/main/'
fileName="GNIpercapita_Data.csv"

DF2csv=pd.read_csv(gitCloudRepo + fileName)

DF2csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                  Indicator Name  Indicator Code  1960  1961  \
# 0    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 1    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 2    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 3    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# ...

# %%
gitCloudRepo='https://github.com/elenapopic542/Deliverable1/raw/main/'
fileName="Inflation_Data.csv"

DF3csv=pd.read_csv(gitCloudRepo + fileName)
DF3csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name  Indicator Code      1960  \
# 0    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 1    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 2    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 3    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# ...

# %% [markdown]
# Step 2: Cleaning the data

# %%
DF1csv.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
DF2csv.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
DF3csv.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')
