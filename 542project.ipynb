# %% [raw]
# Reading-in the datasets into Pandas dataframes from their Github location:

# %%
# call pandas
import pandas as pd # 'pd' is a nickname

gitCloudRepo = 'https://github.com/elenapopic542/Deliverable1/raw/main/'
fileName = "GDPGrowth_Data.csv"

DF1csv = pd.read_csv(gitCloudRepo + fileName)

DF1csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                        Indicator Name     Indicator Code  1960      1961  \
# 0    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 1    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN -2.360093
# 2    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 3    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN -0.274916
# ...

# %%
gitCloudRepo = 'https://github.com/elenapopic542/Deliverable1/raw/main/'
fileName = "GNIpercapita_Data.csv"

DF2csv = pd.read_csv(gitCloudRepo + fileName)

DF2csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                  Indicator Name  Indicator Code  1960  1961  \
# 0    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 1    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 2    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# 3    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN   NaN
# ...

# %%
gitCloudRepo = 'https://github.com/elenapopic542/Deliverable1/raw/main/'
fileName = "Inflation_Data.csv"

DF3csv = pd.read_csv(gitCloudRepo + fileName)
DF3csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name  Indicator Code      1960  \
# 0    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 1    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 2    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 3    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# ...

# %% [markdown]
# Cleaning the data:

# %% [markdown]
# Examining the columns present in each dataframe:

# %%
DF1csv.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
DF2csv.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
DF3csv.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
#Saving a copy of the original file before making any changes 
#original_DF1csv = DF1csv
#original_DF2csv = DF2csv
#original_DF3csv = DF3csv

# %%
#DF1csv = original_DF1csv
#DF2csv = original_DF2csv
#DF3csv = original_DF3csv

# %% [markdown]
# Dropping the columns that are not needed for analysis from each of the dataframes:

# %%
DF1csv.drop(columns=DF1csv.columns[4:44],inplace=True)
DF1csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                        Indicator Name     Indicator Code      2000      2001  \
# 0    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  4.918354  2.369193
# 1    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  0.750996  1.036421
# 2    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG       NaN       NaN
# 3    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  0.967465  2.352157
# ...

# %%
DF2csv.drop(columns=DF2csv.columns[4:44],inplace=True)
DF2csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                  Indicator Name  Indicator Code          2000  \
# 0    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  20390.000000
# 1    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD    656.176751
# 2    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD           NaN
# 3    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD    452.032442
# ...

# %%
DF3csv.drop(columns=DF3csv.columns[4:44],inplace=True)
DF3csv
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name  Indicator Code        2000  \
# 0    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    4.044021
# 1    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    8.601485
# 2    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG         NaN
# 3    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    2.530775
# ...

# %% [markdown]
# Checking the names of the columns:

# %%
DF1csv.columns.to_list()
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
DF2csv.columns.to_list()
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
DF3csv.columns.to_list()
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %% [markdown]
# Eliminating spaces in column names:

# %%
DF1csv.columns.str.replace(" ","",regex=True)
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
DF2csv.columns.str.replace(" ","",regex=True)
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
DF3csv.columns.str.replace(" ","",regex=True)
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
DF1csv.columns = DF1csv.columns.str.replace(" ","",regex=True)

# %%
DF2csv.columns = DF2csv.columns.str.replace(" ","",regex=True)

# %%
DF3csv.columns = DF3csv.columns.str.replace(" ","",regex=True)

# %%
DF1csv.columns.to_list()
# Out:
# ['CountryName',
#  'CountryCode',
#  'IndicatorName',
#  'IndicatorCode',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
DF2csv.columns.to_list()
# Out:
# ['CountryName',
#  'CountryCode',
#  'IndicatorName',
#  'IndicatorCode',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
DF3csv.columns.to_list()
# Out:
# ['CountryName',
#  'CountryCode',
#  'IndicatorName',
#  'IndicatorCode',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %% [markdown]
# Eliminating spaces before the first and last characters in text entry fields:

# %%
DF1csv.CountryName.str.strip()
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 261                         Kosovo
# 262                    Yemen, Rep.
# 263                   South Africa
# 264                         Zambia
# 265                       Zimbabwe
# Name: CountryName, Length: 266, dtype: object

# %%
DF1csv.IndicatorName.str.strip()
# Out:
# 0      GDP per capita growth (annual %)
# 1      GDP per capita growth (annual %)
# 2      GDP per capita growth (annual %)
# 3      GDP per capita growth (annual %)
# 4      GDP per capita growth (annual %)
#                      ...
# 261    GDP per capita growth (annual %)
# 262    GDP per capita growth (annual %)
# 263    GDP per capita growth (annual %)
# 264    GDP per capita growth (annual %)
# 265    GDP per capita growth (annual %)
# Name: IndicatorName, Length: 266, dtype: object

# %%
DF2csv.CountryName.str.strip()
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 261                         Kosovo
# 262                    Yemen, Rep.
# 263                   South Africa
# 264                         Zambia
# 265                       Zimbabwe
# Name: CountryName, Length: 266, dtype: object

# %%
DF2csv.IndicatorName.str.strip()
# Out:
# 0      GNI per capita, Atlas method (current US$)
# 1      GNI per capita, Atlas method (current US$)
# 2      GNI per capita, Atlas method (current US$)
# 3      GNI per capita, Atlas method (current US$)
# 4      GNI per capita, Atlas method (current US$)
#                           ...
# 261    GNI per capita, Atlas method (current US$)
# 262    GNI per capita, Atlas method (current US$)
# 263    GNI per capita, Atlas method (current US$)
# 264    GNI per capita, Atlas method (current US$)
# 265    GNI per capita, Atlas method (current US$)
# Name: IndicatorName, Length: 266, dtype: object

# %%
DF3csv.CountryName.str.strip()
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 261                         Kosovo
# 262                    Yemen, Rep.
# 263                   South Africa
# 264                         Zambia
# 265                       Zimbabwe
# Name: CountryName, Length: 266, dtype: object

# %%
DF3csv.IndicatorName.str.strip()
# Out:
# 0      Inflation, consumer prices (annual %)
# 1      Inflation, consumer prices (annual %)
# 2      Inflation, consumer prices (annual %)
# 3      Inflation, consumer prices (annual %)
# 4      Inflation, consumer prices (annual %)
#                        ...
# 261    Inflation, consumer prices (annual %)
# 262    Inflation, consumer prices (annual %)
# 263    Inflation, consumer prices (annual %)
# 264    Inflation, consumer prices (annual %)
# 265    Inflation, consumer prices (annual %)
# Name: IndicatorName, Length: 266, dtype: object

# %% [markdown]
# Examining the types of data in each dataframe:

# %%
DF1csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    266 non-null    object
#  1   CountryCode    266 non-null    object
#  2   IndicatorName  266 non-null    object
#  3   IndicatorCode  266 non-null    object
#  4   2000           239 non-null    float64
#  5   2001           245 non-null    float64
#  6   2002           246 non-null    float64
#  7   2003           251 non-null    float64
#  8   2004           251 non-null    float64
#  9   2005           252 non-null    float64
#  10  2006           252 non-null    float64
#  11  2007           253 non-null    float64
#  12  2008           252 non-null    float64
#  13  2009           254 non-null    float64
#  14  2010           254 non-null    float64
#  15  2011           254 non-null    float64
#  16  2012           254 non-null    float64
# ...

# %%
DF2csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    266 non-null    object
#  1   CountryCode    266 non-null    object
#  2   IndicatorName  266 non-null    object
#  3   IndicatorCode  266 non-null    object
#  4   2000           230 non-null    float64
#  5   2001           229 non-null    float64
#  6   2002           238 non-null    float64
#  7   2003           239 non-null    float64
#  8   2004           239 non-null    float64
#  9   2005           239 non-null    float64
#  10  2006           240 non-null    float64
#  11  2007           240 non-null    float64
#  12  2008           238 non-null    float64
#  13  2009           239 non-null    float64
#  14  2010           241 non-null    float64
#  15  2011           242 non-null    float64
#  16  2012           242 non-null    float64
# ...

# %%
DF3csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    266 non-null    object
#  1   CountryCode    266 non-null    object
#  2   IndicatorName  266 non-null    object
#  3   IndicatorCode  266 non-null    object
#  4   2000           211 non-null    float64
#  5   2001           216 non-null    float64
#  6   2002           218 non-null    float64
#  7   2003           221 non-null    float64
#  8   2004           222 non-null    float64
#  9   2005           225 non-null    float64
#  10  2006           228 non-null    float64
#  11  2007           230 non-null    float64
#  12  2008           231 non-null    float64
#  13  2009           234 non-null    float64
#  14  2010           236 non-null    float64
#  15  2011           240 non-null    float64
#  16  2012           239 non-null    float64
# ...

# %% [markdown]
# Checking unique values:

# %%
DF1csv['CountryName'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
#Dropping the "Not Classified" observation:
DF1csv = DF1csv[DF1csv["CountryName"].str.contains("Not classified") == False]
DF2csv = DF2csv[DF1csv["CountryName"].str.contains("Not classified") == False]
DF3csv[DF3csv["CountryName"].str.contains("Not classified") == False]
# Out:
# /var/folders/jb/lq0t13x96m323srfn512c7cm0000gn/T/ipykernel_22863/1352920214.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DF2csv = DF2csv[DF1csv["CountryName"].str.contains("Not classified") == False]
#                      CountryName CountryCode  \
# 1    Africa Eastern and Southern         AFE
# 3     Africa Western and Central         AFW
# 4                         Angola         AGO
# 5                        Albania         ALB
# 7                     Arab World         ARB
# ..                           ...         ...
# 258                      Vanuatu         VUT
# 259                        World         WLD
# 260                        Samoa         WSM
# 263                 South Africa         ZAF
# 264                       Zambia         ZMB
#
#                              IndicatorName   IndicatorCode        2000  \
# 1    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    8.601485
# ...

# %% [markdown]
# Checking which cells have missing values:

# %%
DF1csv[DF1csv.isna().any(axis=1)]
# Out:
#                    CountryName CountryCode                     IndicatorName  \
# 2                  Afghanistan         AFG  GDP per capita growth (annual %)
# 11              American Samoa         ASM  GDP per capita growth (annual %)
# 38             Channel Islands         CHI  GDP per capita growth (annual %)
# 51                     Curacao         CUW  GDP per capita growth (annual %)
# 52              Cayman Islands         CYM  GDP per capita growth (annual %)
# 56                    Djibouti         DJI  GDP per capita growth (annual %)
# 69                     Eritrea         ERI  GDP per capita growth (annual %)
# 78               Faroe Islands         FRO  GDP per capita growth (annual %)
# 84                   Gibraltar         GIB  GDP per capita growth (annual %)
# 91                   Greenland         GRL  GDP per capita growth (annual %)
# 93                        Guam         GUM  GDP per capita growth (annual %)
# ...

# %%
DF2csv[DF2csv.isna().any(axis=1)]
# Out:
#                     CountryName CountryCode  \
# 2                   Afghanistan         AFG
# 6                       Andorra         AND
# 7                    Arab World         ARB
# 8          United Arab Emirates         ARE
# 11               American Samoa         ASM
# 22                      Bahrain         BHR
# 27                      Bermuda         BMU
# 38              Channel Islands         CHI
# 50                         Cuba         CUB
# 51                      Curacao         CUW
# 52               Cayman Islands         CYM
# 56                     Djibouti         DJI
# 69                      Eritrea         ERI
# 78                Faroe Islands         FRO
# 84                    Gibraltar         GIB
# 89                       Greece         GRC
# 91                    Greenland         GRL
# 93                         Guam         GUM
# 108                 Isle of Man         IMN
# 110              Not classified         INX
# ...

# %%
DF3csv[DF3csv.isna().any(axis=1)]
# Out:
#                 CountryName CountryCode  \
# 0                     Aruba         ABW
# 2               Afghanistan         AFG
# 6                   Andorra         AND
# 8      United Arab Emirates         ARE
# 9                 Argentina         ARG
# ..                      ...         ...
# 255  British Virgin Islands         VGB
# 256   Virgin Islands (U.S.)         VIR
# 261                  Kosovo         XKX
# 262             Yemen, Rep.         YEM
# 265                Zimbabwe         ZWE
#
#                              IndicatorName   IndicatorCode      2000  \
# 0    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG  4.044021
# 2    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 6    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 8    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 9    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# ...

# %% [markdown]
# Dropping the missing values:

# %%
DF1csv.dropna(inplace=True) 
DF1csv
# Out:
# /var/folders/jb/lq0t13x96m323srfn512c7cm0000gn/T/ipykernel_22863/2938897227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF1csv.dropna(inplace=True)
#                      CountryName CountryCode  \
# 0                          Aruba         ABW
# 1    Africa Eastern and Southern         AFE
# 3     Africa Western and Central         AFW
# 4                         Angola         AGO
# 5                        Albania         ALB
# ..                           ...         ...
# 259                        World         WLD
# 260                        Samoa         WSM
# 263                 South Africa         ZAF
# 264                       Zambia         ZMB
# 265                     Zimbabwe         ZWE
#
# ...

# %%
DF2csv.dropna(inplace=True) 
DF2csv
# Out:
#                      CountryName CountryCode  \
# 0                          Aruba         ABW
# 1    Africa Eastern and Southern         AFE
# 3     Africa Western and Central         AFW
# 4                         Angola         AGO
# 5                        Albania         ALB
# ..                           ...         ...
# 258                      Vanuatu         VUT
# 259                        World         WLD
# 263                 South Africa         ZAF
# 264                       Zambia         ZMB
# 265                     Zimbabwe         ZWE
#
#                                   IndicatorName   IndicatorCode          2000  \
# 0    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD  20390.000000
# 1    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD    656.176751
# 3    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD    452.032442
# 4    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD    360.000000
# ...

# %%
DF3csv.dropna(inplace=True) 
DF3csv
# Out:
#                      CountryName CountryCode  \
# 1    Africa Eastern and Southern         AFE
# 3     Africa Western and Central         AFW
# 4                         Angola         AGO
# 5                        Albania         ALB
# 7                     Arab World         ARB
# ..                           ...         ...
# 258                      Vanuatu         VUT
# 259                        World         WLD
# 260                        Samoa         WSM
# 263                 South Africa         ZAF
# 264                       Zambia         ZMB
#
#                              IndicatorName   IndicatorCode        2000  \
# 1    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    8.601485
# 3    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    2.530775
# 4    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG  324.996872
# 5    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG    0.050018
# ...

# %%
#Verifying if the data in the same columns have an identical datatype:
theZips=zip(DF1csv.dtypes,
            DF2csv.dtypes,
            DF3csv.dtypes)

[x for x in theZips if len(set(x))>1]
# Out:
# []

# %%
#Given that all three dataframes now have columns that have an identical name, location and datatype, 
#we will integrate the dataframes by appending:
inflation=pd.concat([DF1csv,DF2csv,DF3csv])
inflation
# Out:
#                      CountryName CountryCode  \
# 0                          Aruba         ABW
# 1    Africa Eastern and Southern         AFE
# 3     Africa Western and Central         AFW
# 4                         Angola         AGO
# 5                        Albania         ALB
# ..                           ...         ...
# 258                      Vanuatu         VUT
# 259                        World         WLD
# 260                        Samoa         WSM
# 263                 South Africa         ZAF
# 264                       Zambia         ZMB
#
#                              IndicatorName      IndicatorCode       2000  \
# 0         GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   4.918354
# 1         GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   0.750996
# 3         GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   0.967465
# 4         GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  -0.234946
# ...
